# %% [markdown]
# # Repaso 1:  Mostrar por pantalla todos los números naturales impares divisibles por 3 menores a 50.

# %%
# 3 6!!!!!   9 ----  15  -----  21 ------  45!!!!!

for numero in range(3,50,6):

  print(f"----> {numero}")
# Out:
# ----> 3
# ----> 9
# ----> 15
# ----> 21
# ----> 27
# ----> 33
# ----> 39
# ----> 45

# %%
for numero in range(0,50):

  if (numero % 3 == 0): #divisbles por 3

    if  (numero % 2 == 1):

      print(f"----> {numero}")
# Out:
# ----> 3
# ----> 9
# ----> 15
# ----> 21
# ----> 27
# ----> 33
# ----> 39
# ----> 45

# %% [markdown]
# # Repaso 2: Dada esta lista de números encontrar el valor mínimo y la ubicación.   [21,33,-25,85,-3.6, 27]

# %%
# -25

lista = [21,33,-25,85,-3.6, 27]

minimo = lista[0]

for x in lista:

  if ( x < minimo):

    minimo = x


print(f"MINIMO: {minimo}")

#Tarea para la casa !!!!!!!! ---- en qué posición estaba el -25
# Out:
# MINIMO: -25

# %% [markdown]
# # Repaso 3: Guardar los datos de una Persona con un input (doc,edad, nombre, altura, en un diccionario)

# %%
# CASAS :) 
dic = {}

dic["DOC"] = input("Por favor ingresar el documento:\n")
# Out:
# Por favor ingresar la edad:
# 121212

# %%
dic
# Out:
# {'DOC': '121212'}

# %% [markdown]
# # Repaso 4: Ingresar un número con input, y mostrar un mensaje diciendo si es un numero primo o no.

# %%
numero = int ( input("Dame un número... o te mato :( "))

# Un numero es primo cuando ... es divisioble SOLAMENTE por 1 y si mismo..
#5 ----  11----- 

#!!!!!!!!!!!!!!!!

# %%
cadena1 = "Nico es tremendo"

# %%
cadena1.upper()
# Out:
# 'NICO ES TREMENDO'

# %%
cadena1
# Out:
# 'Nico es tremendo'

# %%
cadena1.lower()
# Out:
# 'nico es tremendo'

# %%
cadena1
# Out:
# 'Nico es tremendo'

# %%
cadena2 = "HoLa AmIgO!"

# %%
cadena2.capitalize()
# Out:
# 'Hola amigo!'

# %%
cadena1.title()
# Out:
# 'Nico Es Tremendo'

# %%
cadena1.count("e")
# Out:
# 3

# %%
cadena1.find("Nadia")
# Out:
# -1

# %%
cadena3 = "HoLa amigo como estas maigo!"

# %%
cadena3.find("amigo")
# Out:
# 5

# %%
cadena3.rfind("amigo")
# Out:
# 26

# %%
cadena3.split()  #";"
# Out:
# ['HoLa', 'amigo', 'como', 'estas', 'amigo!']

# %%
variableMagica = cadena3.split()

# %%
variableMagica[::-1]
# Out:
# ['amigo!', 'estas', 'como', 'amigo', 'HoLa']

# %%
cadena1
# Out:
# 'Nico es tremendo'

# %%
"###".join(cadena1)
# Out:
# 'N###i###c###o### ###e###s### ###t###r###e###m###e###n###d###o'

# %%
cadena3
# Out:
# 'HoLa amigo como estas amigo!'

# %%
cadena3.strip("H")
# Out:
# 'oLa amigo como estas amigo!'

# %%
cadena3.replace("s", "L")
# Out:
# 'HoLa amigo como eLtaL amigo!'

# %%
cadena3.replace("a","")
# Out:
# 'HoL migo como ests migo!'

# %%
lista = [21,33,-25,85,-3.6, 27]

# %%
#lista.clear()

# %%
lista
# Out:
# [21, 33, -25, 85, -3.6, 27]

# %%
lista2 = [1,1,1,1,2,2,2,2]

# %%
lista.extend(lista2)

# %%
lista
# Out:
# [21, 33, -25, 85, -3.6, 27, 1, 1, 1, 1, 2, 2, 2, 2]

# %%
lista3 = [4,4,4,lista2]

# %%
lista3
# Out:
# [4, 4, 4, [1, 1, 1, 1, 2, 2, 2, 2]]

# %%
lista
# Out:
# [21, 33, -25, 85, -3.6, 27, 1, 1, 1, 1, 2, 2, 2, 2]

# %%
lista.insert(301, 12121)

# %%
lista.reverse()

# %%
lista
# Out:
# [12121, 2, 2, 2, 2, 1, 1, 1, 1, 27, -3.6, 85, 12121, -25, 33, 21]

# %%
lista.sort(reverse=True)

# %%
lista
# Out:
# [12121, 12121, 85, 33, 27, 21, 2, 2, 2, 2, 1, 1, 1, 1, -3.6, -25]

# %%
conj1 = {1,2,4,"Nico"}
conj2 = {2,6,"Pepe"}
conj3 = {1,2,4,"Nico",8,11}

# %%
conj1.isdisjoint(conj2)
# Out:
# True

# %%
conj1.issubset(conj3)
# Out:
# True

# %%
conj3.issuperset(conj1)
# Out:
# True

# %%
conj1.union(conj2)
# Out:
# {1, 2, 4, 6, 'Nico', 'Pepe'}

# %%
conj3.difference(conj1)
# Out:
# {8, 11}

# %%
set1 = {1,2,3,7}
set2 = {3,4,5}

# %%
set1.difference_update(set2)

# %%
set1
# Out:
# {1, 2, 7}

# %%
conj1.intersection(conj2)
# Out:
# {2}

# %%
conj1.intersection_update(conj2)
conj1
# Out:
# {2}

# %%
conj1
# Out:
# {2}

# %%
diccionario = {"Nombre":"Nicolas", "Edad":32, "Mejor_alumno":"francisco"}

# %%
diccionario["Nombre"]
# Out:
# 'Nicolas'

# %%
diccionario.get("Nombre", "Che esta clave no existe :(") #Me gusta :)
# Out:
# 'Nicolas'

# %%
diccionario.keys()
# Out:
# dict_keys(['Nombre', 'Edad', 'Mejor_alumno'])

# %%
diccionario.values()
# Out:
# dict_values(['Nicolas', 32, 'francisco'])

# %%
diccionario.items()
# Out:
# dict_items([('Nombre', 'Nicolas'), ('Edad', 32), ('Mejor_alumno', 'francisco')])

# %%
for i,j in diccionario.items():

  #print(f"CLAVE -----> {i}  ------> VALOR -----> {j}")

  print(f"############>  {diccionario[i]}")
# Out:
# ############>  Nicolas
# ############>  32
# ############>  francisco

# %%
listaDesafio = [29, -5, -12, 17, 5, 24, 5, 12, 23, 16, 12, 5, -12, 17]

# %%
#1 Borrar repetidos
conjunto = set(listaDesafio)

# %%
listaDesafio = list(conjunto)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b5a36e732251> in <module>()
# ----> 1 listaDesafio = list(conjunto)
#
# NameError: name 'conjunto' is not defined

# %%
listaDesafio.sort(reverse=True)

# %%
listaDesafio
# Out:
# [29, 24, 23, 17, 17, 16, 12, 12, 5, 5, 5, -5, -12, -12]
